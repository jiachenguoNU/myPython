# %%
import pandas as pd
csv_data_path = 'https://raw.githubusercontent.com/turingplanet/pandas-intro/main/public-datasets/country_info.csv'
country_info = pd.read_csv(csv_data_path)

# %%
country_info.head(7) # Display the first few rows of the DataFrame
# Out:
#            Country                               Region  Population  \
# 0     Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1         Albania   EASTERN EUROPE                          3581655
# 2         Algeria   NORTHERN AFRICA                        32930091
# 3  American Samoa   OCEANIA                                   57794
# 4         Andorra   WESTERN EUROPE                            71201
# 5          Angola   SUB-SAHARAN AFRICA                     12127071
# 6        Anguilla               LATIN AMER. & CARIB           13477
#
#    Area (sq. mi.) Pop. Density (per sq. mi.) Coastline (coast/area ratio)  \
# 0          647500                       48,0                         0,00
# 1           28748                      124,6                         1,26
# 2         2381740                       13,8                         0,04
# 3             199                      290,4                        58,29
# ...

# %%
country_info.shape
country_info.columns
country_info.describe()  # Display the first few rows of the DataFrame
# Out:
#          Population  Area (sq. mi.)  GDP ($ per capita)
# count  2.270000e+02    2.270000e+02          226.000000
# mean   2.874028e+07    5.982270e+05         9689.823009
# std    1.178913e+08    1.790282e+06        10049.138513
# min    7.026000e+03    2.000000e+00          500.000000
# 25%    4.376240e+05    4.647500e+03         1900.000000
# 50%    4.786994e+06    8.660000e+04         5550.000000
# 75%    1.749777e+07    4.418110e+05        15700.000000
# max    1.313974e+09    1.707520e+07        55100.000000

# %%
country_info[['Region', 'Population']].head(3)  # Display the first 10 rows of specific columns
# Out:
#                                 Region  Population
# 0        ASIA (EX. NEAR EAST)             31056997
# 1  EASTERN EUROPE                          3581655
# 2  NORTHERN AFRICA                        32930091

# %%
country_info.iloc[7:10]  # Display rows 7 to 10
# Out:
#               Country                   Region  Population  Area (sq. mi.)  \
# 7  Antigua & Barbuda   LATIN AMER. & CARIB           69108             443
# 8          Argentina   LATIN AMER. & CARIB        39921833         2766890
# 9            Armenia      C.W. OF IND. STATES      2976372           29800
#
#   Pop. Density (per sq. mi.) Coastline (coast/area ratio) Net migration  \
# 7                      156,0                        34,54         -6,15
# 8                       14,4                         0,18          0,61
# 9                       99,9                         0,00         -6,47
#
#   Infant mortality (per 1000 births)  GDP ($ per capita) Literacy (%)  \
# 7                              19,46             11000.0         89,0
# 8                              15,18             11200.0         97,1
# 9                              23,28              3500.0         98,6
#
#   Phones (per 1000) Arable (%) Crops (%) Other (%) Climate Birthrate  \
# ...

# %%
country_info.set_index(country_info['Country'].str.strip(), drop =True, inplace=True)

# %%
country_info.head()  # Display the first few rows of the DataFrame
# Out:
#                         Country                               Region  \
# Country
# Afghanistan        Afghanistan         ASIA (EX. NEAR EAST)
# Albania                Albania   EASTERN EUROPE
# Algeria                Algeria   NORTHERN AFRICA
# American Samoa  American Samoa   OCEANIA
# Andorra                Andorra   WESTERN EUROPE
#
#                 Population  Area (sq. mi.) Pop. Density (per sq. mi.)  \
# Country
# Afghanistan       31056997          647500                       48,0
# Albania            3581655           28748                      124,6
# Algeria           32930091         2381740                       13,8
# American Samoa       57794             199                      290,4
# Andorra              71201             468                      152,1
#
#                Coastline (coast/area ratio) Net migration  \
# Country
# Afghanistan                            0,00         23,06
# Albania                                1,26         -4,93
# ...

# %%
country_info.loc['Albania': 'China']  # 注意这里是loc方法，使用索引名来访问行， 而不是iloc方法
# Out:
#                                     Country  \
# Country
# Albania                            Albania
# Algeria                            Algeria
# American Samoa              American Samoa
# Andorra                            Andorra
# Angola                              Angola
# Anguilla                          Anguilla
# Antigua & Barbuda        Antigua & Barbuda
# Argentina                        Argentina
# Armenia                            Armenia
# Aruba                                Aruba
# Australia                        Australia
# Austria                            Austria
# Azerbaijan                      Azerbaijan
# Bahamas, The                  Bahamas, The
# Bahrain                            Bahrain
# Bangladesh                      Bangladesh
# Barbados                          Barbados
# Belarus                            Belarus
# Belgium                            Belgium
# Belize                              Belize
# ...
